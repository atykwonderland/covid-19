# %%
import pandas as pd

# Import Data
df = pd.read_csv('/kaggle/input/novel-corona-virus-2019-dataset/covid_19_data.csv')
df_world = df.copy()
# Out:
# /kaggle/input/novel-corona-virus-2019-dataset/time_series_covid_19_confirmed.csv
# /kaggle/input/novel-corona-virus-2019-dataset/time_series_covid_19_recovered.csv
# /kaggle/input/novel-corona-virus-2019-dataset/COVID19_open_line_list.csv
# /kaggle/input/novel-corona-virus-2019-dataset/time_series_covid_19_deaths.csv
# /kaggle/input/novel-corona-virus-2019-dataset/covid_19_data.csv
# /kaggle/input/novel-corona-virus-2019-dataset/COVID19_line_list_data.csv

# %%
# Get Input
province = input("province/state (if none, write NA): ") 
country = input("country/region: ") 
date = input("date (write as mm/dd/yyyy): ")
# Out:
# province/state (if none, write NA): Hebei
# country/region: Mainland China
# date (write as mm/dd/yyyy): 01/22/2020

# %%
#Clean data to match inputs
df_world = df_world.drop(['SNo'], axis=1)
df_date = df_world[df_world['ObservationDate'] == date]
df_country_date = df_date[df_date['Country/Region'] == country]

#Get sums of Confirmed, Deaths, Recovered
if province == "NA":
    #add up add regions in country for cases
    total = df_country_date.sum(axis = 0, skipna = True, numeric_only = True)
else:
    df_province_date = df_country_date[df_country_date['Province/State'] == province]
    total = df_province_date.sum(axis = 0, skipna = True, numeric_only = True)

#Print the totals
print(total)
# Out:
#    ObservationDate  Province/State  Country/Region      Last Update  \
# 0       01/22/2020           Anhui  Mainland China  1/22/2020 17:00
# 1       01/22/2020         Beijing  Mainland China  1/22/2020 17:00
# 2       01/22/2020       Chongqing  Mainland China  1/22/2020 17:00
# 3       01/22/2020          Fujian  Mainland China  1/22/2020 17:00
# 4       01/22/2020           Gansu  Mainland China  1/22/2020 17:00
# 5       01/22/2020       Guangdong  Mainland China  1/22/2020 17:00
# 6       01/22/2020         Guangxi  Mainland China  1/22/2020 17:00
# 7       01/22/2020         Guizhou  Mainland China  1/22/2020 17:00
# 8       01/22/2020          Hainan  Mainland China  1/22/2020 17:00
# 9       01/22/2020           Hebei  Mainland China  1/22/2020 17:00
# 10      01/22/2020    Heilongjiang  Mainland China  1/22/2020 17:00
# 11      01/22/2020           Henan  Mainland China  1/22/2020 17:00
# 13      01/22/2020           Hubei  Mainland China  1/22/2020 17:00
# 14      01/22/2020           Hunan  Mainland China  1/22/2020 17:00
# 15      01/22/2020  Inner Mongolia  Mainland China  1/22/2020 17:00
# 16      01/22/2020         Jiangsu  Mainland China  1/22/2020 17:00
# 17      01/22/2020         Jiangxi  Mainland China  1/22/2020 17:00
# 18      01/22/2020           Jilin  Mainland China  1/22/2020 17:00
# 19      01/22/2020        Liaoning  Mainland China  1/22/2020 17:00
# 21      01/22/2020         Ningxia  Mainland China  1/22/2020 17:00
# 22      01/22/2020         Qinghai  Mainland China  1/22/2020 17:00
# 23      01/22/2020         Shaanxi  Mainland China  1/22/2020 17:00
# 24      01/22/2020        Shandong  Mainland China  1/22/2020 17:00
# 25      01/22/2020        Shanghai  Mainland China  1/22/2020 17:00
# 26      01/22/2020          Shanxi  Mainland China  1/22/2020 17:00
# 27      01/22/2020         Sichuan  Mainland China  1/22/2020 17:00
# 29      01/22/2020         Tianjin  Mainland China  1/22/2020 17:00
# 30      01/22/2020           Tibet  Mainland China  1/22/2020 17:00
# 32      01/22/2020        Xinjiang  Mainland China  1/22/2020 17:00
# 33      01/22/2020          Yunnan  Mainland China  1/22/2020 17:00
# 34      01/22/2020        Zhejiang  Mainland China  1/22/2020 17:00
#
#     Confirmed  Deaths  Recovered
# 0         1.0     0.0        0.0
# 1        14.0     0.0        0.0
# 2         6.0     0.0        0.0
# 3         1.0     0.0        0.0
# 4         0.0     0.0        0.0
# 5        26.0     0.0        0.0
# 6         2.0     0.0        0.0
# 7         1.0     0.0        0.0
# 8         4.0     0.0        0.0
# 9         1.0     0.0        0.0
# 10        0.0     0.0        0.0
# 11        5.0     0.0        0.0
# 13      444.0    17.0       28.0
# 14        4.0     0.0        0.0
# 15        0.0     0.0        0.0
# 16        1.0     0.0        0.0
# 17        2.0     0.0        0.0
# 18        0.0     0.0        0.0
# 19        2.0     0.0        0.0
# 21        1.0     0.0        0.0
# 22        0.0     0.0        0.0
# 23        0.0     0.0        0.0
# 24        2.0     0.0        0.0
# 25        9.0     0.0        0.0
# 26        1.0     0.0        0.0
# 27        5.0     0.0        0.0
# 29        4.0     0.0        0.0
# 30        0.0     0.0        0.0
# 32        0.0     0.0        0.0
# 33        1.0     0.0        0.0
# 34       10.0     0.0        0.0
